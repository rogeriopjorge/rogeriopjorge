# %% [markdown]
# # Usando o modelo Word2Vec

# %% [markdown]
# ### Passo 1 - importanto as bibliotecas e carregando o modelo
# Vamos importar as bibliotecas que utilizaremos e carregar o modelo. Para usar o formato binário, usamos a função ```load_word2vec_format```, caso contrário, basta usar a função ```load()```

# %%
from gensim.models import KeyedVectors, Word2Vec
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import numpy as np
import seaborn as sns
import pandas as pd

# %%
w2v_model = KeyedVectors.load_word2vec_format('corpus_incor.bin', binary=True)
w2v_model = Word2Vec.load("corpus_incor.model")

# %% [markdown]
# ### Passo 2 - Encontrando palavras similares
# Vamos buscar as 20 palavras mais similares a algumas palavras-chave, como nome de personagens. Como no pré-processamento, temos que escrever as palavras sem acento e apenas com caracteres alfanuméricos, senão a palavra não será encontrada no vocabulário.

# %%
w2v_model.wv.most_similar(positive=['paciente'], topn=20)
# Out:
# [('pcte', 0.8937312364578247),
#  ('pora_m', 0.8376988172531128),
#  ('informar', 0.8071781396865845),
#  ('paceinte', 0.803879976272583),
#  ('relatar', 0.8025108575820923),
#  ('acreditar', 0.7928047776222229),
#  ('referir', 0.7816880941390991),
#  ('atual', 0.766898512840271),
#  ('pôr', 0.7620572447776794),
#  ('hoje', 0.7613320350646973),
#  ('ja', 0.7606526017189026),
#  ('acompanhante', 0.759823203086853),
#  ('comparecer_consulto', 0.7576414346694946),
#  ('comparecer', 0.7551825046539307),
#  ('clinicar', 0.7548825740814209),
#  ('evoluir', 0.748433530330658),
#  ('motivar', 0.7476863861083984),
#  ('consulto', 0.7471294403076172),
#  ('poliqueixosa', 0.7401421070098877),
#  ('assintoma_tica', 0.7393687963485718)]

# %%
w2v_model.wv.most_similar(positive=['resultar'], topn=20)
# Out:
# [('checar_resultar', 0.7822169065475464),
#  ('pedir', 0.7580186128616333),
#  ('checar', 0.7562212944030762),
#  ('realizar', 0.7557631731033325),
#  ('trazer', 0.7351621389389038),
#  ('externamente', 0.7310433387756348),
#  ('enviar', 0.727679967880249),
#  ('solicitaa', 0.7183263897895813),
#  ('trara', 0.7147064208984375),
#  ('realizaa', 0.706816554069519),
#  ('prontua_rir', 0.7027946710586548),
#  ('relatorio', 0.6967707872390747),
#  ('adendo', 0.6961084604263306),
#  ('broncoscopia_lba', 0.692104697227478),
#  ('prontuario', 0.6877666115760803),
#  ('coletado', 0.6866676807403564),
#  ('solicitar_novamente', 0.6837844848632812),
#  ('sera', 0.6789026260375977),
#  ('exame', 0.6773985624313354),
#  ('requisia', 0.6753379106521606)]

# %%
w2v_model.wv.most_similar(positive=['estudar'], topn=20)
# Out:
# [('estudo', 0.7609248161315918),
#  ('identificar', 0.7243603467941284),
#  ('tomogra_ficos', 0.7100784182548523),
#  ('cintilogra_ficar', 0.7030670642852783),
#  ('observar', 0.6997094750404358),
#  ('conveniente', 0.699251115322113),
#  ('comparaa', 0.6974700689315796),
#  ('defeito_perfusionais', 0.6955167651176453),
#  ('comparaa_exame', 0.6943652033805847),
#  ('permitir', 0.6933790445327759),
#  ('exame_anterior', 0.6928980350494385),
#  ('achar', 0.6894950270652771),
#  ('noto', 0.6872063875198364),
#  ('transir_toracoabdominal', 0.676289439201355),
#  ('comparativo', 0.674665093421936),
#  ('mecanismo_limitaa', 0.6712932586669922),
#  ('interpretaa', 0.6703473925590515),
#  ('demonstrar', 0.6672708988189697),
#  ('contrastaa', 0.659384548664093),
#  ('eletrofisiologico', 0.6451596021652222)]

# %%
w2v_model.wv.most_similar(positive=['apresentar'], topn=20)
# Out:
# [('alar_m', 0.8926902413368225),
#  ('persistir', 0.8282312154769897),
#  ('tamba_m', 0.8259330987930298),
#  ('persistir_ncia', 0.8085350394248962),
#  ('nestes', 0.7992094159126282),
#  ('importante', 0.7851788997650146),
#  ('permanecer', 0.7838892340660095),
#  ('piorar', 0.7830489277839661),
#  ('episa_dios', 0.7759069204330444),
#  ('mantar_m', 0.7678236365318298),
#  ('ltimos', 0.7614003419876099),
#  ('ha', 0.7597528696060181),
#  ('ha_aproximadamente', 0.7569042444229126),
#  ('pora_m', 0.7510052919387817),
#  ('associar', 0.7503399848937988),
#  ('notar', 0.7456156015396118),
#  ('inalterado', 0.7345514297485352),
#  ('evoluir', 0.7334181070327759),
#  ('episa_dio', 0.7327386140823364),
#  ('referir', 0.7268708348274231)]

# %%
w2v_model.wv.most_similar(positive=['analisar'], topn=20)
# Out:
# [('ana_lise', 0.7420651912689209),
#  ('prejudicar', 0.6844244003295898),
#  ('visualizaa', 0.6762022376060486),
#  ('prejudicar_dever', 0.6607526540756226),
#  ('detectar', 0.6442273855209351),
#  ('patola_gica', 0.625912070274353),
#  ('obtido', 0.6147252321243286),
#  ('indispona', 0.6085232496261597),
#  ('visibilizados', 0.6002296209335327),
#  ('hiperdina', 0.5945490002632141),
#  ('anatomia', 0.5936816930770874),
#  ('espectral', 0.5924525260925293),
#  ('paucidade', 0.5913859009742737),
#  ('valorizar', 0.5899364948272705),
#  ('funa_diasta', 0.5848342180252075),
#  ('reduca', 0.5847307443618774),
#  ('manoma', 0.5810336470603943),
#  ('doppler_colorir', 0.5799770355224609),
#  ('comprovar', 0.5795620679855347),
#  ('veis', 0.5784233808517456)]

# %%
w2v_model.wv.most_similar(positive=['realizar'], topn=20)
# Out:
# [('realizaa', 0.8936310410499573),
#  ('fazer', 0.8205647468566895),
#  ('vestir', 0.7857791185379028),
#  ('efetuado', 0.7784721851348877),
#  ('liberar', 0.7653870582580566),
#  ('trazer', 0.7594348192214966),
#  ('resultar', 0.7557632327079773),
#  ('exame', 0.7550339698791504),
#  ('solicitaa', 0.7486252188682556),
#  ('feito', 0.7448877692222595),
#  ('pedir', 0.7414277791976929),
#  ('datar', 0.730475127696991),
#  ('aguardar_realizaa', 0.7213168144226074),
#  ('avaliaa', 0.7152804136276245),
#  ('exame_laboratorial', 0.709636926651001),
#  ('cancelar', 0.7045055627822876),
#  ('descrever', 0.7016105651855469),
#  ('perder', 0.6968015432357788),
#  ('ja', 0.6943227052688599),
#  ('necessidade', 0.6919293403625488)]

# %%
w2v_model.wv.most_similar(positive=['utilizar'], topn=20)
# Out:
# [('usar', 0.8673813343048096),
#  ('fazer_usar', 0.8109410405158997),
#  ('usar_irregular', 0.7847108840942383),
#  ('recordar', 0.7715431451797485),
#  ('medicaa_es', 0.7712072134017944),
#  ('inicar', 0.7665825486183167),
#  ('medicaa', 0.7659239768981934),
#  ('acabar', 0.762531578540802),
#  ('medicamento', 0.7609395980834961),
#  ('bomba', 0.7598917484283447),
#  ('contar_nuo', 0.749795138835907),
#  ('regularmente', 0.7489714622497559),
#  ('conseguir_comprar', 0.7459951639175415),
#  ('dispensar', 0.737636148929596),
#  ('remedio', 0.7341278791427612),
#  ('sair', 0.7325307726860046),
#  ('seretide_diskus', 0.7308565378189087),
#  ('lembrar_nome', 0.7305042147636414),
#  ('bamifix', 0.7299619317054749),
#  ('prescrito', 0.7249951362609863)]

# %%
w2v_model.wv.most_similar(positive=['doenca'], topn=20)
# Out:
# [('reumatologica', 0.7931467890739441),
#  ('doena', 0.7865076065063477),
#  ('demencia', 0.7294250726699829),
#  ('autoimune', 0.7289579510688782),
#  ('neuromuscular', 0.7187910079956055),
#  ('miopatia', 0.7088167071342468),
#  ('interstical', 0.7035499811172485),
#  ('crioglobulinemia', 0.6961654424667358),
#  ('reumatola_gica', 0.6872228384017944),
#  ('colagenoses', 0.684367299079895),
#  ('ceratite', 0.6798362731933594),
#  ('acometimento', 0.6795701384544373),
#  ('polineuropatia', 0.6774429082870483),
#  ('phc', 0.6767280101776123),
#  ('hipovolemia', 0.6644508242607117),
#  ('ario', 0.6635961532592773),
#  ('sorologica', 0.6611086130142212),
#  ('crohn', 0.6600249409675598),
#  ('hipoteses', 0.6575446128845215),
#  ('like', 0.6539640426635742)]

# %%
w2v_model.wv.most_similar(positive=['febre'], topn=20)
# Out:
# [('febre_aferir', 0.93861323595047),
#  ('expectoraa_esverdear', 0.909867525100708),
#  ('tossir', 0.9072619676589966),
#  ('oc', 0.9069226980209351),
#  ('sudorese_noturna', 0.9042288661003113),
#  ('expectoraa', 0.9000115394592285),
#  ('tossir_produtivo', 0.8957145810127258),
#  ('calafrio', 0.8912271857261658),
#  ('negar_febre', 0.8864766359329224),
#  ('tossir_seco', 0.8797327280044556),
#  ('tossir_expectoraa', 0.8766896724700928),
#  ('hemoptoico', 0.8762170076370239),
#  ('febre_vespertino', 0.8760716319084167),
#  ('hemoptoicos', 0.8752694129943848),
#  ('amarelar', 0.8591703176498413),
#  ('sibilar_ncia', 0.8527288436889648),
#  ('hiporexia', 0.8507938385009766),
#  ('tossir_secrea', 0.8473423719406128),
#  ('prostraa', 0.8434209227561951),
#  ('expectoraa_amarelar', 0.8428752422332764)]

# %%
w2v_model.wv.most_similar(positive=['hipertensao'], topn=20)
# Out:
# [('hipertenso', 0.7353385090827942),
#  ('has_primar', 0.7347686886787415),
#  ('has_essencial', 0.7333290576934814),
#  ('ivestigaa', 0.7118876576423645),
#  ('hipertenso_arterial', 0.7006683945655823),
#  ('leso_rga', 0.6900297403335571),
#  ('investigaa_causar', 0.6875035762786865),
#  ('essencial', 0.683997392654419),
#  ('arterial_causar', 0.6786396503448486),
#  ('has', 0.6768892407417297),
#  ('has_dificil', 0.6659941673278809),
#  ('tep_cronicar', 0.6632884740829468),
#  ('hipertesa', 0.6604666113853455),
#  ('causar_secundar', 0.6578454971313477),
#  ('naprix', 0.6507307291030884),
#  ('sahos', 0.648461639881134),
#  ('has_resistente', 0.6466829776763916),
#  ('hp', 0.6427724957466125),
#  ('apneia_sono', 0.6367394328117371),
#  ('fatores_riscar', 0.6339476704597473)]

# %%
w2v_model.wv.most_similar(positive=['laudo'], topn=20)
# Out:
# [('externo', 0.8045333623886108),
#  ('filmar', 0.7922608256340027),
#  ('aguardar_laudo', 0.7623860836029053),
#  ('descrer', 0.7581900358200073),
#  ('mostrar', 0.754987359046936),
#  ('laudo_oficial', 0.751517653465271),
#  ('provisorio', 0.7337965369224548),
#  ('vestir', 0.7299777269363403),
#  ('laudo_verbal', 0.729637086391449),
#  ('provisa', 0.7075726985931396),
#  ('comparativo', 0.7054167985916138),
#  ('tomografia', 0.7026868462562561),
#  ('isite', 0.6982028484344482),
#  ('demonstrar', 0.6956954002380371),
#  ('prontua_rir', 0.6928479671478271),
#  ('revelar', 0.6919578909873962),
#  ('radiologia', 0.6882805824279785),
#  ('revisar', 0.6832245588302612),
#  ('encontrar', 0.6816704273223877),
#  ('exame', 0.6767998933792114)]

# %%
w2v_model.wv.most_similar(positive=['central'], topn=20)
# Out:
# [('perifa_rico', 0.7617511749267578),
#  ('hipocaptante', 0.7218335866928101),
#  ('feixe', 0.7115393877029419),
#  ('rodear', 0.7032995223999023),
#  ('perfunde', 0.7012631893157959),
#  ('extenso', 0.6681464910507202),
#  ('arteriolares', 0.6598466634750366),
#  ('lm_lid', 0.6505244970321655),
#  ('reas', 0.6482924818992615),
#  ('predominar', 0.6471065878868103),
#  ('paredesbronquicas', 0.6318457126617432),
#  ('coletor', 0.6282427310943604),
#  ('septais', 0.627177894115448),
#  ('espessamento', 0.626867413520813),
#  ('via_a', 0.6258753538131714),
#  ('grosseiro', 0.6223052740097046),
#  ('condicionar', 0.6193936467170715),
#  ('bfe', 0.6179006099700928),
#  ('liar', 0.6178569197654724),
#  ('vvaa', 0.6145125031471252)]

# %%
w2v_model.wv.most_similar(positive=['aparentemente'], topn=20)
# Out:
# [('aparentar', 0.8769978284835815),
#  ('habitualmente', 0.76524418592453),
#  ('imagem', 0.734234094619751),
#  ('componente', 0.7169694304466248),
#  ('difa_cil', 0.715236246585846),
#  ('vel', 0.707186758518219),
#  ('achar', 0.7030669450759888),
#  ('evolutivo', 0.7023715972900391),
#  ('observar', 0.6938779354095459),
#  ('descrever', 0.6801900267601013),
#  ('evolutivamente', 0.6746102571487427),
#  ('veis', 0.6723954081535339),
#  ('pequeno', 0.6625407934188843),
#  ('ssima', 0.6492611765861511),
#  ('impresso', 0.6444973945617676),
#  ('descrito', 0.6433558464050293),
#  ('comparar', 0.6417112350463867),
#  ('encontrar', 0.6337270736694336),
#  ('exame_anterior', 0.6335633397102356),
#  ('dificultar', 0.6322439908981323)]

# %%
w2v_model.wv.most_similar(positive=['anatomopatologico'], topn=20)
# Out:
# [('anatomopatola_gico', 0.804381251335144),
#  ('designar', 0.7921065092086792),
#  ('congelaa', 0.7914050221443176),
#  ('revisar_laminar', 0.7775919437408447),
#  ('guo', 0.775884747505188),
#  ('histologia', 0.7724645733833313),
#  ('bx', 0.7553894519805908),
#  ('tranbronquica', 0.7467883229255676),
#  ('revisar', 0.7380415797233582),
#  ('transtoracica', 0.7364519834518433),
#  ('constituida', 0.7347010970115662),
#  ('epiplon', 0.7328701019287109),
#  ('biopsia', 0.7184470891952515),
#  ('tuberculoma', 0.7167854905128479),
#  ('toracoscopia', 0.7158826589584351),
#  ('endobronquica', 0.7156964540481567),
#  ('actina', 0.7138550877571106),
#  ('excisional', 0.7133105993270874),
#  ('ihq', 0.7091156244277954),
#  ('bia_psia', 0.707364022731781)]

# %%
w2v_model.wv.most_similar(positive=['febre'], topn=20)
# Out:
# [('febre_aferir', 0.93861323595047),
#  ('expectoraa_esverdear', 0.909867525100708),
#  ('tossir', 0.9072619676589966),
#  ('oc', 0.9069226980209351),
#  ('sudorese_noturna', 0.9042288661003113),
#  ('expectoraa', 0.9000115394592285),
#  ('tossir_produtivo', 0.8957145810127258),
#  ('calafrio', 0.8912271857261658),
#  ('negar_febre', 0.8864766359329224),
#  ('tossir_seco', 0.8797327280044556),
#  ('tossir_expectoraa', 0.8766896724700928),
#  ('hemoptoico', 0.8762170076370239),
#  ('febre_vespertino', 0.8760716319084167),
#  ('hemoptoicos', 0.8752694129943848),
#  ('amarelar', 0.8591703176498413),
#  ('sibilar_ncia', 0.8527288436889648),
#  ('hiporexia', 0.8507938385009766),
#  ('tossir_secrea', 0.8473423719406128),
#  ('prostraa', 0.8434209227561951),
#  ('expectoraa_amarelar', 0.8428752422332764)]

# %%
w2v_model.wv.most_similar(positive=['lesoes'], topn=20)
# Out:
# [('leso_es', 0.8629124760627747),
#  ('lea', 0.7889965772628784),
#  ('leso', 0.7768052816390991),
#  ('lesao', 0.7734289169311523),
#  ('troficas', 0.7257294058799744),
#  ('seguimentares', 0.6829223036766052),
#  ('mtas', 0.6757426857948303),
#  ('lessa', 0.6596978902816772),
#  ('eritematoso', 0.6562422513961792),
#  ('dermatologicas', 0.6507135033607483),
#  ('eritemato', 0.6484970450401306),
#  ('papuloso', 0.6338204145431519),
#  ('descamativas', 0.62750643491745),
#  ('crostosas', 0.6271350979804993),
#  ('cavitadas', 0.6244181394577026),
#  ('triarteriais', 0.6133064031600952),
#  ('ulcerar', 0.6021211743354797),
#  ('hipocromicas', 0.6008987426757812),
#  ('lesoe', 0.5960747599601746),
#  ('hiperemiadas', 0.5927536487579346)]

# %%
w2v_model.wv.most_similar(positive=['semelhante'], topn=20)
# Out:
# [('surgir', 0.7965190410614014),
#  ('anterior', 0.7809929251670837),
#  ('inalterado', 0.7684872150421143),
#  ('aparecimento', 0.7326298952102661),
#  ('comparaa', 0.7273454070091248),
#  ('surgimento', 0.7240490913391113),
#  ('apresentar', 0.717201828956604),
#  ('relaa', 0.7138389348983765),
#  ('pequeno', 0.7137835621833801),
#  ('alar_m', 0.7112473249435425),
#  ('comparar', 0.7056976556777954),
#  ('evolutivo', 0.7037709355354309),
#  ('permanecer', 0.700104832649231),
#  ('inalterado_relaa', 0.7000449299812317),
#  ('comparaa_exame', 0.6909366846084595),
#  ('tamba_m', 0.6855864524841309),
#  ('similar', 0.685090184211731),
#  ('desaparecimento', 0.6822065114974976),
#  ('resolua', 0.6788759231567383),
#  ('exame_anterior', 0.6737809181213379)]

# %%
w2v_model.wv.most_similar(positive=['cicatricial'], topn=20)
# Out:
# [('parenquimatoso_aspecto', 0.7836736440658569),
#  ('consolidativo', 0.7634983062744141),
#  ('retraa', 0.7593012452125549),
#  ('bra_nquicas', 0.7483788728713989),
#  ('o_ngula', 0.7411343455314636),
#  ('bronquiolar', 0.741039514541626),
#  ('subsegmentos', 0.7382197380065918),
#  ('destruia', 0.7377984523773193),
#  ('endobra_nquica', 0.7280173301696777),
#  ('fibrocicatricial', 0.7279613018035889),
#  ('sequelar', 0.7247811555862427),
#  ('lingula', 0.7245969772338867),
#  ('correspondente', 0.7218824625015259),
#  ('acometida', 0.7152507305145264),
#  ('trave', 0.7063122987747192),
#  ('lingular', 0.702743411064148),
#  ('lse', 0.7002329230308533),
#  ('fibroatelecta_sica', 0.699757993221283),
#  ('fibroatelectasico', 0.6971084475517273),
#  ('lsd', 0.6965502500534058)]

# %%
w2v_model.wv.most_similar(positive=['inflamatoria'], topn=20)
# Out:
# [('inflamata_rir', 0.770484209060669),
#  ('proliferativo', 0.7511833906173706),
#  ('inflamatorio', 0.7509523630142212),
#  ('miopatia', 0.7499470710754395),
#  ('sobrepor', 0.7263110280036926),
#  ('retiniano', 0.7231274843215942),
#  ('autoimunes', 0.7229318022727966),
#  ('vascula', 0.7198569178581238),
#  ('xantogranulomatosa', 0.7179940938949585),
#  ('infeccsiosso', 0.6962801218032837),
#  ('inflar', 0.693286657333374),
#  ('rinopatia', 0.6921287775039673),
#  ('granulomatosa', 0.6908471584320068),
#  ('wegner', 0.6905622482299805),
#  ('atividade', 0.6892580986022949),
#  ('cronicidade', 0.6855286955833435),
#  ('arquiteturais', 0.6835150122642517),
#  ('pseudotumor', 0.6800698041915894),
#  ('bronquioloca_ntrico', 0.6690267324447632),
#  ('miastenia', 0.668366551399231)]

# %% [markdown]
# ### Passo 3 - Grau de similaridade
# Agora, vamos medir o quanto duas palavras são similarses, ou seja, o quanto elas aparecem no mesmo contexto ao longo dos sete livros.

# %%
w2v_model.wv.similarity("doenca", 'dor')
# Out:
# -0.016905678

# %%
w2v_model.wv.similarity("paciente", 'sequela')
# Out:
# 0.15059403

# %% [markdown]
# ### Passo 4 - Palavra fora de contexto
# Das palavras enviadas, qual está fora do contexto?
#
# Vimos que às vezes os resultados não fazem muito sentido para nós, humanos.. Lembre-se de que isso foi gerado de acordo com a forma em que as palavras estavam em nosso corpus.

# %%
w2v_model.wv.doesnt_match(['doenca', 'dor', 'hemodinamica'])
# Out:
# 'dor'

# %%
w2v_model.wv.doesnt_match(['febre', 'tumor', 'paciente'])
# Out:
# 'tumor'

# %% [markdown]
# ### Passo 5 - Analogias
#
# Qual palavra está para **terra** assim como **chuva** está para **sol**?

# %%
w2v_model.wv.most_similar(positive=["febre", "dor"], negative=["paciente"], topn=3)
# Out:
# [('reger_dorsal', 0.8034459352493286),
#  ('dorsalgia', 0.7725465297698975),
#  ('reger_cervical', 0.744373619556427)]

# %%
w2v_model.wv.most_similar(positive=["montanha", "nuvem"], negative=["casa"], topn=3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-04394289c4bb> in <module>
# ----> 1 w2v_model.wv.most_similar(positive=["montanha", "nuvem"], negative=["casa"], topn=3)
#
# D:\Users\roger\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     760                 mean.append(weight * key)
#     761             else:
# --> 762                 mean.append(weight * self.get_vector(key, norm=True))
#     763                 if self.has_index_for(key):
#     764                     all_keys.add(self.get_index(key))
#
# D:\Users\roger\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in get_vector(self, key, norm)
#     420
#     421         """
# --> 422         index = self.get_index(key)
#     423         if norm:
#     424             self.fill_norms()
#
# D:\Users\roger\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in get_index(self, key, default)
#     394             return default
#     395         else:
# --> 396             raise KeyError(f"Key '{key}' not present")
#     397
#     398     def get_vector(self, key, norm=False):
#
# KeyError: "Key 'montanha' not present"

# %%
w2v_model.wv.most_similar(positive=["escola", "sala"], negative=["trem"], topn=3)
# Out:
# [('limite', 0.6873146891593933),
#  ('alunar', 0.6806097030639648),
#  ('estudante', 0.6531786918640137)]

# %% [markdown]
# ### Passo 6 - Top palavras mais e menos similares

# %%
w2v_model.wv.most_similar(positive=["doenca"],topn=3)
# Out:
# [('reumatologica', 0.7931467890739441),
#  ('doena', 0.7865076065063477),
#  ('demencia', 0.7294250726699829)]

# %%
w2v_model.wv.most_similar(negative=["doenca"],topn=3)
# Out:
# [('quinto', 0.5529424548149109),
#  ('x', 0.5474557876586914),
#  ('sabado', 0.5333513021469116)]

# %% [markdown]
# ### Passo 7 - Visualização t-SNE
# Vamos plotar nossos vetores de 32 dimensões em gráficos bidimensionais para tentar encontrar padrões interessantes.
#
# Para isso, usaremos a implementação ```t-SNE``` do ```scikit-learn```.
#
# Para tornar as visualizações mais relevantes, examinaremos as relações entre uma palavra de consulta (em vermelho), suas palavras mais semelhantes no modelo (em azul) e outras palavras do vocabulário (em verde).

# %%
def tsnescatterplot(model, word, list_names):
    # Plota os resultados do algoritmo de redução de dimensionalidade t-SNE dos vetores de uma palavra de consulta,
    # sua lista de palavras mais semelhantes e uma lista de palavras.
    arrays = np.empty((0, 32), dtype='f')
    word_labels = [word]
    color_list  = ['red']

    # adiciona o vetor da palavra de consulta
    arrays = np.append(arrays, model.wv.__getitem__([word]), axis=0)
    
    # pega a lsita das palavras mais similares
    close_words = model.wv.most_similar([word])
    
    # adiciona o vetor de cada uma das palavras mais proximas no array
    for wrd_score in close_words:
        wrd_vector = model.wv.__getitem__([wrd_score[0]])
        word_labels.append(wrd_score[0])
        color_list.append('blue')
        arrays = np.append(arrays, wrd_vector, axis=0)

        
    # adiciona o vetor de cada uma das palavras da lista list_names ao array
    for wrd in list_names:
        wrd_vector = model.wv.__getitem__([wrd])
        word_labels.append(wrd)
        color_list.append('green')
        arrays = np.append(arrays, wrd_vector, axis=0)
                
    # Reduz a dimensionalidade com PCA
    reduc = PCA(n_components=18).fit_transform(arrays)
    
    # Encontra as coorendadas t-SNE para duas dimensoes
    np.set_printoptions(suppress=True)
    
    Y = TSNE(n_components=2, random_state=0, perplexity=15).fit_transform(reduc)
    
    # Seta as variaveis para plotar
    df = pd.DataFrame({'x': [x for x in Y[:, 0]],
                       'y': [y for y in Y[:, 1]],
                       'words': word_labels,
                       'color': color_list})
    
    fig, _ = plt.subplots()
    fig.set_size_inches(9, 9)
    
    # Grafico basico
    p1 = sns.regplot(data=df,
                     x="x",
                     y="y",
                     fit_reg=False,
                     marker="o",
                     scatter_kws={'s': 40,
                                  'facecolors': df['color']
                                 }
                    )
    
    # Adiciona anotações com um loop
    for line in range(0, df.shape[0]):
         p1.text(df["x"][line],
                 df['y'][line],
                 '  ' + df["words"][line].title(),
                 horizontalalignment='left',
                 verticalalignment='bottom', size='medium',
                 color=df['color'][line],
                 weight='normal'
                ).set_size(15)

    
    plt.xlim(Y[:, 0].min()-50, Y[:, 0].max()+50)
    plt.ylim(Y[:, 1].min()-50, Y[:, 1].max()+50)
            
    plt.title('t-SNE visualization for {}'.format(word.title()))

# %%
wordT = 'doenca'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'paciente'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'hipertensao'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'diabete'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'febre'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'dor'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'hemodinamica'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'calafrio'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'gravidez'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'sono'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'internar'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'estudar'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'quadro'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'hepatico'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'pulmao'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'coracao'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-f5b9147036c8> in <module>
#       1 wordT = 'coracao'
#       2
# ----> 3 tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])
#
# D:\Users\roger\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     760                 mean.append(weight * key)
#     761             else:
# --> 762                 mean.append(weight * self.get_vector(key, norm=True))
#     763                 if self.has_index_for(key):
#     764                     all_keys.add(self.get_index(key))
#
# D:\Users\roger\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in get_vector(self, key, norm)
#     420
#     421         """
# --> 422         index = self.get_index(key)
#     423         if norm:
#     424             self.fill_norms()
#
# D:\Users\roger\anaconda3\lib\site-packages\gensim\models\keyedvectors.py in get_index(self, key, default)
#     394             return default
#     395         else:
# --> 396             raise KeyError(f"Key '{key}' not present")
#     397
#     398     def get_vector(self, key, norm=False):
#
# KeyError: "Key 'coracao' not present"

# %%
wordT = 'perna'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'cancer'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'suspeitar'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'hemorragia'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'trombose'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'sindrome'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])
