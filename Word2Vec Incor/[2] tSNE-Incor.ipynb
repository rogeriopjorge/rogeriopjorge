# %% [markdown]
# # Usando o modelo Word2Vec

# %% [markdown]
# ### Passo 1 - importanto as bibliotecas e carregando o modelo
# Vamos importar as bibliotecas que utilizaremos e carregar o modelo. Para usar o formato binário, usamos a função ```load_word2vec_format```, caso contrário, basta usar a função ```load()```

# %%
from gensim.models import KeyedVectors, Word2Vec
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import numpy as np
import seaborn as sns
import pandas as pd
# Out:
# D:\Users\roger\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
w2v_model = KeyedVectors.load_word2vec_format('corpus_incor.bin', binary=True)
w2v_model = Word2Vec.load("corpus_incor.model")

# %% [markdown]
# ### Passo 2 - Encontrando palavras similares
# Vamos buscar as 20 palavras mais similares a algumas palavras-chave, como nome de personagens. Como no pré-processamento, temos que escrever as palavras sem acento e apenas com caracteres alfanuméricos, senão a palavra não será encontrada no vocabulário.

# %%
w2v_model.wv.most_similar(positive=['paciente'], topn=20)
# Out:
# [('dispneia_mmrc', 0.988469123840332),
#  ('quadrar', 0.9831125736236572),
#  ('piorar', 0.9824720621109009),
#  ('dispneia', 0.9813026189804077),
#  ('mantar', 0.9808855056762695),
#  ('seco', 0.980863630771637),
#  ('referir', 0.9802567958831787),
#  ('mrc', 0.9797724485397339),
#  ('atual', 0.9785175919532776),
#  ('precordialgia', 0.97786545753479),
#  ('queixar', 0.9775198101997375),
#  ('expectoracao', 0.9756890535354614),
#  ('ortopneia', 0.9750942587852478),
#  ('esporadica', 0.9748221635818481),
#  ('tossir', 0.9742065668106079),
#  ('sincopar', 0.972248375415802),
#  ('negar_febre', 0.9714453220367432),
#  ('palpitacoes', 0.971248984336853),
#  ('relatar', 0.9708427786827087),
#  ('produtivo', 0.9707694053649902)]

# %%
w2v_model.wv.most_similar(positive=['resultar'], topn=20)
# Out:
# [('histoquimica', 0.9843007922172546),
#  ('examinar', 0.9798157811164856),
#  ('positivo', 0.9775782823562622),
#  ('celulas', 0.9732304811477661),
#  ('grocott', 0.9717651009559631),
#  ('jirovecii', 0.9714568853378296),
#  ('material', 0.9705989360809326),
#  ('imunodifusao', 0.969358503818512),
#  ('pesquisar', 0.9680951237678528),
#  ('representativo', 0.96735018491745),
#  ('caerobia', 0.9672579765319824),
#  ('bk', 0.9667145013809204),
#  ('neelsen', 0.9659624099731445),
#  ('pesq', 0.9639723300933838),
#  ('imuno', 0.9623157978057861),
#  ('mycobacterium', 0.9614747762680054),
#  ('coloracao', 0.961428165435791),
#  ('cel', 0.9611808061599731),
#  ('aspergilus', 0.9602797627449036),
#  ('micobact', 0.9598636627197266)]

# %%
w2v_model.wv.most_similar(positive=['estudar'], topn=20)
# Out:
# [('significativo', 0.9795383214950562),
#  ('cintilar', 0.973212480545044),
#  ('doppler', 0.9716106057167053),
#  ('alteracoes', 0.9639288187026978),
#  ('cintilografia', 0.9614244699478149),
#  ('ausencia', 0.9607760906219482),
#  ('evolutivo', 0.9566266536712646),
#  ('rim', 0.9566200375556946),
#  ('sinal', 0.9532081484794617),
#  ('evidenciar', 0.9529953002929688),
#  ('ateromatose', 0.95212721824646),
#  ('perfusao', 0.9519717693328857),
#  ('arterias', 0.9516407251358032),
#  ('isquemia', 0.9512518644332886),
#  ('dinamica', 0.9510916471481323),
#  ('vaso', 0.9486596584320068),
#  ('glomerular', 0.9479001760482788),
#  ('compativeis', 0.9478873014450073),
#  ('renal', 0.9468857049942017),
#  ('induzir', 0.9468807578086853)]

# %%
w2v_model.wv.most_similar(positive=['apresentar'], topn=20)
# Out:
# [('importante', 0.9804904460906982),
#  ('moderar', 0.9771057367324829),
#  ('atrio', 0.9596095681190491),
#  ('alteracao', 0.9566019773483276),
#  ('dilatacao', 0.9554679989814758),
#  ('comprometimento', 0.9536324143409729),
#  ('movimentacao', 0.9535648822784424),
#  ('atipica', 0.9529402256011963),
#  ('ser', 0.9508101940155029),
#  ('aortica', 0.9502461552619934),
#  ('ectasia', 0.9479201436042786),
#  ('possivel', 0.9473792910575867),
#  ('derramar', 0.9473762512207031),
#  ('tenue', 0.9469974040985107),
#  ('paradoxal', 0.9448525905609131),
#  ('troncar', 0.9439236521720886),
#  ('pericardico', 0.9433088302612305),
#  ('analisar', 0.9432448148727417),
#  ('movimentar', 0.9430539608001709),
#  ('arteria_pulmonar', 0.9426472187042236)]

# %%
w2v_model.wv.most_similar(positive=['analisar'], topn=20)
# Out:
# [('paradoxal', 0.9851961135864258),
#  ('interventricular', 0.9847564697265625),
#  ('tenue', 0.984505295753479),
#  ('ecogenicidade', 0.9839301109313965),
#  ('excentrica', 0.983272910118103),
#  ('diminuida', 0.9829298853874207),
#  ('hve', 0.9822918772697449),
#  ('simetrica', 0.9813732504844666),
#  ('insuf', 0.9810831546783447),
#  ('minimo', 0.980384349822998),
#  ('indiretos', 0.9803707599639893),
#  ('espessar', 0.9796338081359863),
#  ('acinesia', 0.9788575768470764),
#  ('ecocardio', 0.9786605834960938),
#  ('miocardio', 0.9781633615493774),
#  ('movimentar', 0.9780041575431824),
#  ('dir', 0.9775323271751404),
#  ('ateromatoso', 0.9772485494613647),
#  ('alteracao', 0.9763411283493042),
#  ('desempenhar', 0.9759814739227295)]

# %%
w2v_model.wv.most_similar(positive=['realizar'], topn=20)
# Out:
# [('cirurgia', 0.9862373471260071),
#  ('encontrar', 0.9830199480056763),
#  ('doenca', 0.9829508066177368),
#  ('tb', 0.9819357395172119),
#  ('encaminhar', 0.9815857410430908),
#  ('junho', 0.9813199043273926),
#  ('investigacao', 0.9811041355133057),
#  ('minimos', 0.9807087182998657),
#  ('tomografica', 0.9804806709289551),
#  ('relatorio', 0.9792544841766357),
#  ('pregresso', 0.9785417914390564),
#  ('especificar', 0.9785369634628296),
#  ('impressao', 0.9779544472694397),
#  ('bronquite', 0.9778505563735962),
#  ('toracica', 0.9777941703796387),
#  ('optar', 0.9772875308990479),
#  ('comparar', 0.9772310256958008),
#  ('angina', 0.9771569967269897),
#  ('identificar', 0.9770192503929138),
#  ('cirurgica', 0.9768587350845337)]

# %%
w2v_model.wv.most_similar(positive=['utilizar'], topn=20)
# Out:
# [('sind', 0.9960537552833557),
#  ('alca', 0.9955500364303589),
#  ('producao', 0.9953811764717102),
#  ('constante', 0.9952837228775024),
#  ('antibioticoterapia', 0.9952830076217651),
#  ('hemodinamica', 0.9952723979949951),
#  ('hipoxemico', 0.9952680468559265),
#  ('convocacao', 0.9952161312103271),
#  ('higiene', 0.9951798915863037),
#  ('colecistectomia', 0.9951671957969666),
#  ('auscultar', 0.9949091076850891),
#  ('cabeca', 0.9948724508285522),
#  ('nascimento', 0.9948597550392151),
#  ('pot', 0.9948291182518005),
#  ('exacerbador', 0.9948197603225708),
#  ('cirugia', 0.9947080016136169),
#  ('vertebral', 0.9946755170822144),
#  ('pronto', 0.9946464896202087),
#  ('dono', 0.9945691823959351),
#  ('caixa', 0.9945592880249023)]

# %%
w2v_model.wv.most_similar(positive=['doenca'], topn=20)
# Out:
# [('comparar', 0.990968644618988),
#  ('sequela', 0.9900667667388916),
#  ('relacionar', 0.9893286228179932),
#  ('toracica', 0.9881540536880493),
#  ('aspiracao', 0.9874460697174072),
#  ('impressao', 0.9867664575576782),
#  ('lesoes', 0.9867514371871948),
#  ('tomografica', 0.9851971864700317),
#  ('investigacao', 0.9850320219993591),
#  ('persistir', 0.9841976761817932),
#  ('infeccioso', 0.9840338230133057),
#  ('haver', 0.9839648604393005),
#  ('encontrar', 0.9837888479232788),
#  ('identificar', 0.9833977222442627),
#  ('semelhante', 0.9830313920974731),
#  ('provavel', 0.9829867482185364),
#  ('realizar', 0.9829508066177368),
#  ('estaveis', 0.9826446771621704),
#  ('bronquiolite', 0.9813070893287659),
#  ('possibilidade', 0.9812342524528503)]

# %%
w2v_model.wv.most_similar(positive=['febre'], topn=20)
# Out:
# [('perda_pesar', 0.994718074798584),
#  ('esverdear', 0.9941036701202393),
#  ('progressivo', 0.9915603995323181),
#  ('esporadica', 0.9915351867675781),
#  ('mmrc', 0.9911331534385681),
#  ('sibilancia', 0.991075873374939),
#  ('queixar', 0.9910380244255066),
#  ('amarelar', 0.9903329610824585),
#  ('hemoptoicos', 0.9887881875038147),
#  ('produtivo', 0.9884687662124634),
#  ('atual', 0.9874898195266724),
#  ('edema_mmii', 0.9871524572372437),
#  ('noturna', 0.9869232773780823),
#  ('expectoracao', 0.9863728880882263),
#  ('mantar', 0.9858719110488892),
#  ('mrc', 0.9857029318809509),
#  ('negar_febre', 0.984162449836731),
#  ('seco', 0.9838300943374634),
#  ('quadrar', 0.9836796522140503),
#  ('cansaco', 0.9834426641464233)]

# %%
w2v_model.wv.most_similar(positive=['hipertensao'], topn=20)
# Out:
# [('ateromatoso', 0.9889795184135437),
#  ('laudo', 0.9881851673126221),
#  ('agudo', 0.9877336621284485),
#  ('externo', 0.9876837730407715),
#  ('lesao', 0.9867410063743591),
#  ('sugerir', 0.9867315292358398),
#  ('mostrar', 0.9856457710266113),
#  ('esofagica', 0.985575795173645),
#  ('laringite', 0.9851456880569458),
#  ('focal', 0.9844829440116882),
#  ('calcificacao', 0.983837902545929),
#  ('tcar', 0.9836874008178711),
#  ('hipoperfusao', 0.9834266901016235),
#  ('ateromatose', 0.9832155108451843),
#  ('fibrose', 0.9831353425979614),
#  ('trajeto', 0.9830973148345947),
#  ('luminal', 0.9830756187438965),
#  ('periferica', 0.9830108880996704),
#  ('adjacente', 0.9829132556915283),
#  ('hiperinsuflacao', 0.9828505516052246)]

# %%
w2v_model.wv.most_similar(positive=['laudo'], topn=20)
# Out:
# [('angio', 0.9914181232452393),
#  ('trajeto', 0.9910151958465576),
#  ('captacao', 0.9899547696113586),
#  ('sugerir', 0.9897298812866211),
#  ('hilo', 0.9895534515380859),
#  ('aferente', 0.9894278049468994),
#  ('cortical', 0.9892075061798096),
#  ('externo', 0.989115297794342),
#  ('luminal', 0.9890256524085999),
#  ('obliteracao', 0.9887784123420715),
#  ('esofagica', 0.9887231588363647),
#  ('deles', 0.9887108206748962),
#  ('repolarizacao', 0.9885866045951843),
#  ('perfusional', 0.9882009625434875),
#  ('hipertensao', 0.9881851673126221),
#  ('cadeia', 0.9880269765853882),
#  ('central', 0.9879361391067505),
#  ('endobronquica', 0.9874154329299927),
#  ('calcificacao', 0.9873776435852051),
#  ('perifericas', 0.9869749546051025)]

# %%
w2v_model.wv.most_similar(positive=['central'], topn=20)
# Out:
# [('pervia', 0.9954490661621094),
#  ('lingular', 0.9951037168502808),
#  ('nesses', 0.9950737953186035),
#  ('grosseiro', 0.9950056076049805),
#  ('fibroso', 0.9950023889541626),
#  ('opacificacao', 0.9947301149368286),
#  ('retracao', 0.9946342706680298),
#  ('calcular', 0.9944817423820496),
#  ('distar', 0.9942737817764282),
#  ('disseminacao', 0.9942442178726196),
#  ('fusiforme', 0.9942007660865784),
#  ('existir', 0.9940428137779236),
#  ('aparentemente', 0.9940398931503296),
#  ('hialinizacao', 0.9939991235733032),
#  ('portal', 0.9939795732498169),
#  ('linfonodomegalia', 0.9938230514526367),
#  ('destacar', 0.9936742782592773),
#  ('trajeto', 0.9935755729675293),
#  ('alongar', 0.9935417175292969),
#  ('costal', 0.9934006929397583)]

# %%
w2v_model.wv.most_similar(positive=['aparentemente'], topn=20)
# Out:
# [('antigo', 0.9970117807388306),
#  ('fundica', 0.9962577819824219),
#  ('transicao', 0.996140718460083),
#  ('angiomiolipomas', 0.9961137175559998),
#  ('erosao', 0.9958983659744263),
#  ('papel', 0.9958844184875488),
#  ('av', 0.9957995414733887),
#  ('existir', 0.9956854581832886),
#  ('lingua', 0.9955075979232788),
#  ('fibrotica', 0.995308518409729),
#  ('diafragmatica', 0.9952318072319031),
#  ('expressivo', 0.9952149391174316),
#  ('rx', 0.9951753616333008),
#  ('prejuizo', 0.9950565099716187),
#  ('anatomopatologico', 0.9950227737426758),
#  ('unica', 0.9949219226837158),
#  ('admitir', 0.9948363304138184),
#  ('bolar', 0.9948155879974365),
#  ('abscesso', 0.994796872138977),
#  ('cavo', 0.9947113990783691)]

# %%
w2v_model.wv.most_similar(positive=['anatomopatologico'], topn=20)
# Out:
# [('lingua', 0.9957529306411743),
#  ('juntar', 0.9953998327255249),
#  ('bxtb', 0.9953323602676392),
#  ('aparentemente', 0.9950227737426758),
#  ('feito', 0.9945818185806274),
#  ('conter', 0.9945578575134277),
#  ('silicose', 0.9945002794265747),
#  ('limite', 0.9943896532058716),
#  ('hx', 0.99431312084198),
#  ('facial', 0.9942071437835693),
#  ('zonar', 0.9941951036453247),
#  ('sobretudo', 0.9941467046737671),
#  ('varicoso', 0.9940735697746277),
#  ('similar', 0.9939612150192261),
#  ('celular', 0.9939178824424744),
#  ('bolar', 0.9938580989837646),
#  ('hidronefrose', 0.9938390851020813),
#  ('cerebral', 0.99383544921875),
#  ('htd', 0.9938163757324219),
#  ('anasarco', 0.9937571287155151)]

# %%
w2v_model.wv.most_similar(positive=['febre'], topn=20)
# Out:
# [('perda_pesar', 0.994718074798584),
#  ('esverdear', 0.9941036701202393),
#  ('progressivo', 0.9915603995323181),
#  ('esporadica', 0.9915351867675781),
#  ('mmrc', 0.9911331534385681),
#  ('sibilancia', 0.991075873374939),
#  ('queixar', 0.9910380244255066),
#  ('amarelar', 0.9903329610824585),
#  ('hemoptoicos', 0.9887881875038147),
#  ('produtivo', 0.9884687662124634),
#  ('atual', 0.9874898195266724),
#  ('edema_mmii', 0.9871524572372437),
#  ('noturna', 0.9869232773780823),
#  ('expectoracao', 0.9863728880882263),
#  ('mantar', 0.9858719110488892),
#  ('mrc', 0.9857029318809509),
#  ('negar_febre', 0.984162449836731),
#  ('seco', 0.9838300943374634),
#  ('quadrar', 0.9836796522140503),
#  ('cansaco', 0.9834426641464233)]

# %%
w2v_model.wv.most_similar(positive=['lesoes'], topn=20)
# Out:
# [('mostrar', 0.9893099665641785),
#  ('doenca', 0.9867514371871948),
#  ('sequela', 0.9855136275291443),
#  ('toracica', 0.9841432571411133),
#  ('agudo', 0.9837555885314941),
#  ('relacionar', 0.9832355976104736),
#  ('identificar', 0.98282790184021),
#  ('provavel', 0.9825206995010376),
#  ('multiplas', 0.9824740290641785),
#  ('encontrar', 0.9821366667747498),
#  ('haver', 0.981650173664093),
#  ('lse', 0.98146653175354),
#  ('semelhante', 0.9805856943130493),
#  ('comparar', 0.9801204800605774),
#  ('surgir', 0.9798456430435181),
#  ('luminal', 0.9797009825706482),
#  ('externo', 0.9793480634689331),
#  ('investigacao', 0.9788315296173096),
#  ('hemitorax', 0.9784497022628784),
#  ('pervio', 0.9782092571258545)]

# %%
w2v_model.wv.most_similar(positive=['semelhante'], topn=20)
# Out:
# [('llii', 0.9918199777603149),
#  ('surgir', 0.9898827075958252),
#  ('surgimento', 0.9897301197052002),
#  ('aspiracao', 0.9895345568656921),
#  ('bolhar', 0.9891209602355957),
#  ('confluente', 0.9888838529586792),
#  ('escavacoes', 0.9888390898704529),
#  ('atelectasicas', 0.9887738823890686),
#  ('inflamatoria', 0.9884727001190186),
#  ('inespecificos', 0.9884280562400818),
#  ('sequelar', 0.9884169101715088),
#  ('delimitar', 0.988315999507904),
#  ('comparar', 0.9882148504257202),
#  ('multiplas', 0.9879418015480042),
#  ('incaracteristicos', 0.9879045486450195),
#  ('alar', 0.9878649711608887),
#  ('contexto', 0.9878188371658325),
#  ('hemitorax', 0.9877163767814636),
#  ('peribroncovascular', 0.98748779296875),
#  ('cicatricial', 0.9874463677406311)]

# %%
w2v_model.wv.most_similar(positive=['cicatricial'], topn=20)
# Out:
# [('calcificacao', 0.9947565197944641),
#  ('bandar', 0.9945534467697144),
#  ('retratil', 0.9939936399459839),
#  ('regioes', 0.9933416843414307),
#  ('inespecificos', 0.9927129149436951),
#  ('surgir', 0.9921429753303528),
#  ('apice', 0.9918575286865234),
#  ('bolhar', 0.9916817545890808),
#  ('apices', 0.9916659593582153),
#  ('formar', 0.9912209510803223),
#  ('sequelar', 0.9905514121055603),
#  ('multiplas', 0.9902784824371338),
#  ('inflamatoria', 0.989973783493042),
#  ('bronquio', 0.9897685647010803),
#  ('lobular', 0.9897056221961975),
#  ('focal', 0.989369809627533),
#  ('adjacente', 0.9890776872634888),
#  ('centrar', 0.988869845867157),
#  ('subpleurais', 0.9886580109596252),
#  ('llii', 0.9886576533317566)]

# %%
w2v_model.wv.most_similar(positive=['inflamatoria'], topn=20)
# Out:
# [('calcificacao', 0.9955111742019653),
#  ('peribroncovascular', 0.994399905204773),
#  ('llii', 0.9942954182624817),
#  ('sequelar', 0.9940442442893982),
#  ('agrupar', 0.9937161207199097),
#  ('contexto', 0.9930104613304138),
#  ('formar', 0.9929916858673096),
#  ('trajeto', 0.992794394493103),
#  ('incaracteristicos', 0.9924473762512207),
#  ('confluente', 0.9924055337905884),
#  ('agudo', 0.9923903346061707),
#  ('bolhar', 0.9920210838317871),
#  ('interior', 0.9916006326675415),
#  ('delimitar', 0.9915760159492493),
#  ('multiplas', 0.991431474685669),
#  ('determinar', 0.9913052320480347),
#  ('exuberante', 0.9912108182907104),
#  ('externo', 0.9911624789237976),
#  ('acentuacao', 0.9907282590866089),
#  ('escavacoes', 0.9906920194625854)]

# %% [markdown]
# ### Passo 3 - Grau de similaridade
# Agora, vamos medir o quanto duas palavras são similarses, ou seja, o quanto elas aparecem no mesmo contexto ao longo dos sete livros.

# %%
w2v_model.wv.similarity("doenca", 'dor')
# Out:
# 0.9144238

# %%
w2v_model.wv.similarity("paciente", 'sequela')
# Out:
# 0.7898221

# %% [markdown]
# ### Passo 4 - Palavra fora de contexto
# Das palavras enviadas, qual está fora do contexto?
#
# Vimos que às vezes os resultados não fazem muito sentido para nós, humanos.. Lembre-se de que isso foi gerado de acordo com a forma em que as palavras estavam em nosso corpus.

# %%
w2v_model.wv.doesnt_match(['doenca', 'dor', 'hemodinamica'])
# Out:
# 'dor'

# %%
w2v_model.wv.doesnt_match(['febre', 'tumor', 'paciente'])
# Out:
# 'paciente'

# %% [markdown]
# ### Passo 5 - Analogias
#
# Qual palavra está para **terra** assim como **chuva** está para **sol**?

# %%
w2v_model.wv.most_similar(positive=["febre", "dor"], negative=["paciente"], topn=3)
# Out:
# [('comparecer', 0.9745628833770752),
#  ('levantar', 0.9726479649543762),
#  ('evoluir', 0.9722230434417725)]

# %%
w2v_model.wv.most_similar(positive=["montanha", "nuvem"], negative=["casa"], topn=3)
# Out:
# [('nevoar', 0.7380039095878601),
#  ('ceu', 0.7246636152267456),
#  ('florestar_proibir', 0.7180446982383728)]

# %%
w2v_model.wv.most_similar(positive=["escola", "sala"], negative=["trem"], topn=3)
# Out:
# [('limite', 0.6873146891593933),
#  ('alunar', 0.6806097030639648),
#  ('estudante', 0.6531786918640137)]

# %% [markdown]
# ### Passo 6 - Top palavras mais e menos similares

# %%
w2v_model.wv.most_similar(positive=["doenca"],topn=3)
# Out:
# [('comparar', 0.990968644618988),
#  ('sequela', 0.9900667667388916),
#  ('relacionar', 0.9893286228179932)]

# %%
w2v_model.wv.most_similar(negative=["doenca"],topn=3)
# Out:
# [('sodio', -0.3884838819503784),
#  ('espironolactona', -0.3886176645755768),
#  ('vos', -0.3907378315925598)]

# %% [markdown]
# ### Passo 7 - Visualização t-SNE
# Vamos plotar nossos vetores de 32 dimensões em gráficos bidimensionais para tentar encontrar padrões interessantes.
#
# Para isso, usaremos a implementação ```t-SNE``` do ```scikit-learn```.
#
# Para tornar as visualizações mais relevantes, examinaremos as relações entre uma palavra de consulta (em vermelho), suas palavras mais semelhantes no modelo (em azul) e outras palavras do vocabulário (em verde).

# %%
def tsnescatterplot(model, word, list_names):
    # Plota os resultados do algoritmo de redução de dimensionalidade t-SNE dos vetores de uma palavra de consulta,
    # sua lista de palavras mais semelhantes e uma lista de palavras.
    arrays = np.empty((0, 32), dtype='f')
    word_labels = [word]
    color_list  = ['red']

    # adiciona o vetor da palavra de consulta
    arrays = np.append(arrays, model.wv.__getitem__([word]), axis=0)
    
    # pega a lsita das palavras mais similares
    close_words = model.wv.most_similar([word])
    
    # adiciona o vetor de cada uma das palavras mais proximas no array
    for wrd_score in close_words:
        wrd_vector = model.wv.__getitem__([wrd_score[0]])
        word_labels.append(wrd_score[0])
        color_list.append('blue')
        arrays = np.append(arrays, wrd_vector, axis=0)

        
    # adiciona o vetor de cada uma das palavras da lista list_names ao array
    for wrd in list_names:
        wrd_vector = model.wv.__getitem__([wrd])
        word_labels.append(wrd)
        color_list.append('green')
        arrays = np.append(arrays, wrd_vector, axis=0)
                
    # Reduz a dimensionalidade com PCA
    reduc = PCA(n_components=18).fit_transform(arrays)
    
    # Encontra as coorendadas t-SNE para duas dimensoes
    np.set_printoptions(suppress=True)
    
    Y = TSNE(n_components=2, random_state=0, perplexity=15).fit_transform(reduc)
    
    # Seta as variaveis para plotar
    df = pd.DataFrame({'x': [x for x in Y[:, 0]],
                       'y': [y for y in Y[:, 1]],
                       'words': word_labels,
                       'color': color_list})
    
    fig, _ = plt.subplots()
    fig.set_size_inches(9, 9)
    
    # Grafico basico
    p1 = sns.regplot(data=df,
                     x="x",
                     y="y",
                     fit_reg=False,
                     marker="o",
                     scatter_kws={'s': 40,
                                  'facecolors': df['color']
                                 }
                    )
    
    # Adiciona anotações com um loop
    for line in range(0, df.shape[0]):
         p1.text(df["x"][line],
                 df['y'][line],
                 '  ' + df["words"][line].title(),
                 horizontalalignment='left',
                 verticalalignment='bottom', size='medium',
                 color=df['color'][line],
                 weight='normal'
                ).set_size(15)

    
    plt.xlim(Y[:, 0].min()-50, Y[:, 0].max()+50)
    plt.ylim(Y[:, 1].min()-50, Y[:, 1].max()+50)
            
    plt.title('t-SNE visualization for {}'.format(word.title()))

# %%
wordT = 'doenca'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'paciente'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'hipertensao'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'diabete'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'febre'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'dor'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'hemodinamica'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'calafrio'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'gravidez'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'sono'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'internar'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'estudar'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'quadro'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'hepatico'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'pulmao'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'coracao'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'perna'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'cancer'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'suspeitar'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'hemorragia'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'trombose'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'sindrome'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %% [markdown]
# Agora, vamos [gerar nuvens de palavras](https://github.com/lisaterumi/word2vec-harry-potter-portugues/blob/main/%5B3%5D%20Nuvem-palavra-Harry-Potter.ipynb) para cada um dos livros em separado.
