# %% [markdown]
# # Usando o modelo Word2Vec

# %% [markdown]
# ### Passo 1 - importanto as bibliotecas e carregando o modelo
# Vamos importar as bibliotecas que utilizaremos e carregar o modelo. Para usar o formato binário, usamos a função ```load_word2vec_format```, caso contrário, basta usar a função ```load()```

# %%
from gensim.models import KeyedVectors, Word2Vec
import matplotlib.pyplot as plt

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import numpy as np
import seaborn as sns
import pandas as pd
# Out:
# D:\Users\roger\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
w2v_model = KeyedVectors.load_word2vec_format('corpus_scielo.bin', binary=True)
w2v_model = Word2Vec.load("corpus_scielo.model")

# %% [markdown]
# ### Passo 2 - Encontrando palavras similares
# Vamos buscar as 20 palavras mais similares a algumas palavras-chave, como nome de personagens. Como no pré-processamento, temos que escrever as palavras sem acento e apenas com caracteres alfanuméricos, senão a palavra não será encontrada no vocabulário.

# %%
w2v_model.wv.most_similar(positive=['paciente'], topn=20)
# Out:
# [('doente', 0.8946942687034607),
#  ('acompanhamento_ambulatorial', 0.8443160653114319),
#  ('seguimento_ambulatorial', 0.7680782675743103),
#  ('portador', 0.757635235786438),
#  ('assintomaticos', 0.7523159384727478),
#  ('seguimento', 0.7443747520446777),
#  ('paciente_portador', 0.7183480262756348),
#  ('sintomatica', 0.7170695066452026),
#  ('assintomatico', 0.7140562534332275),
#  ('cardiopata', 0.7119709253311157),
#  ('previo', 0.7107471823692322),
#  ('acima_ano', 0.6964806914329529),
#  ('paciente_evoluiram', 0.694086492061615),
#  ('paciente_ambulatoriais', 0.6936964392662048),
#  ('sintomatico', 0.6903651356697083),
#  ('clinicamente', 0.6882051825523376),
#  ('hospitalizar', 0.6868528723716736),
#  ('historiar_prever', 0.6866545677185059),
#  ('doencas_neurologicas', 0.684267520904541),
#  ('diabeticos', 0.6827419996261597)]

# %%
w2v_model.wv.most_similar(positive=['resultar'], topn=20)
# Out:
# [('conclusoes', 0.8186510801315308),
#  ('conclusao', 0.796541690826416),
#  ('mostrar', 0.7699568867683411),
#  ('satisfatorios', 0.7603068351745605),
#  ('haver', 0.7594062685966492),
#  ('demonstrar', 0.7527880668640137),
#  ('evidenciar', 0.7509267330169678),
#  ('constatar', 0.7467706799507141),
#  ('entretanto', 0.7330023646354675),
#  ('verificar', 0.7323015928268433),
#  ('permitir_concluir', 0.7313789129257202),
#  ('nao_haver', 0.7312875390052795),
#  ('pôr', 0.7301322817802429),
#  ('entanto', 0.7250059247016907),
#  ('satisfatoria', 0.7171130180358887),
#  ('todavia', 0.716838002204895),
#  ('significativo', 0.7089424133300781),
#  ('significancia_estatistica', 0.7080415487289429),
#  ('diferenca', 0.7075605392456055),
#  ('inconclusivo', 0.7026070356369019)]

# %%
w2v_model.wv.most_similar(positive=['estudar'], topn=20)
# Out:
# [('quantitativo', 0.7843282222747803),
#  ('presentar_estudar', 0.7571206092834473),
#  ('comparativo', 0.7410885691642761),
#  ('analisar', 0.7322498559951782),
#  ('objetivo_presentar', 0.728878378868103),
#  ('objetivo', 0.720099925994873),
#  ('objetivo_descrever', 0.718901515007019),
#  ('investigar', 0.7151265144348145),
#  ('estudar_longitudinal', 0.6977485418319702),
#  ('exploratorio', 0.6910127401351929),
#  ('estudar_descritivo', 0.689426064491272),
#  ('retrospectivo', 0.685899019241333),
#  ('analitico', 0.6776069402694702),
#  ('objetivou_descrever', 0.6766476631164551),
#  ('objetivou_caracterizar', 0.6764991283416748),
#  ('descrever', 0.6762404441833496),
#  ('cortar_transversal', 0.6729289293289185),
#  ('metodos', 0.6725728511810303),
#  ('tracar_perfil', 0.6667361855506897),
#  ('transversal', 0.6659046411514282)]

# %%
w2v_model.wv.most_similar(positive=['apresentar'], topn=20)
# Out:
# [('observar', 0.8854156732559204),
#  ('encontrar', 0.8409996032714844),
#  ('mostrar', 0.8347253799438477),
#  ('semelhante', 0.8293982744216919),
#  ('constatar', 0.8128446340560913),
#  ('baixo', 0.80390465259552),
#  ('acentuar', 0.8005123734474182),
#  ('elevar', 0.7968056201934814),
#  ('verificar', 0.7960453033447266),
#  ('evidente', 0.792431116104126),
#  ('indicativo', 0.7910937666893005),
#  ('maior', 0.787336528301239),
#  ('variar', 0.7872928977012634),
#  ('haver', 0.7763926386833191),
#  ('correlacionar', 0.7763127684593201),
#  ('revelar', 0.7733701467514038),
#  ('relacao_direta', 0.7709710597991943),
#  ('indicar', 0.7690702080726624),
#  ('nao_diferir', 0.7672157883644104),
#  ('relacao', 0.7649424076080322)]

# %%
w2v_model.wv.most_similar(positive=['analisar'], topn=20)
# Out:
# [('analisar_comparativo', 0.8953595757484436),
#  ('quantitativo', 0.8249285817146301),
#  ('basear', 0.8184195756912231),
#  ('dar', 0.7633448243141174),
#  ('referente', 0.7534960508346558),
#  ('qualitativo_quantitativo', 0.7506628036499023),
#  ('estudar', 0.7322497963905334),
#  ('mediante', 0.7289335131645203),
#  ('quantitativo_qualitativo', 0.7223299145698547),
#  ('descritivamente', 0.712344765663147),
#  ('feito', 0.7080609202384949),
#  ('atraves', 0.7017722129821777),
#  ('investigar', 0.6999058723449707),
#  ('categorizacao', 0.6995474100112915),
#  ('dar_obtido', 0.6942276954650879),
#  ('descrever', 0.6933659911155701),
#  ('levantar', 0.6929027438163757),
#  ('identificar', 0.6864843964576721),
#  ('descritivo', 0.6861609220504761),
#  ('efetuada', 0.6855229139328003)]

# %%
w2v_model.wv.most_similar(positive=['realizar'], topn=20)
# Out:
# [('feito', 0.8165788650512695),
#  ('proceder', 0.811532735824585),
#  ('efetuada', 0.8024616837501526),
#  ('constar', 0.7900367975234985),
#  ('conduzir', 0.7874153852462769),
#  ('efetuados', 0.7834360599517822),
#  ('consistir', 0.7803806066513062),
#  ('fazer', 0.7739371657371521),
#  ('metodos', 0.7681865692138672),
#  ('submetido', 0.7554585933685303),
#  ('atraves', 0.7494684457778931),
#  ('realizacao', 0.7337754368782043),
#  ('mediante', 0.7327641248703003),
#  ('utilizar', 0.7257644534111023),
#  ('efetuadas', 0.7201434373855591),
#  ('totalizar', 0.6954810619354248),
#  ('selecionados', 0.6953148245811462),
#  ('analisar_comparativo', 0.6952990293502808),
#  ('retrospectivo', 0.6889824867248535),
#  ('aplicar', 0.6826505661010742)]

# %%
w2v_model.wv.most_similar(positive=['utilizar'], topn=20)
# Out:
# [('aplicar', 0.8810112476348877),
#  ('empregar', 0.847598671913147),
#  ('basear', 0.8052276372909546),
#  ('atraves', 0.7956433296203613),
#  ('mediante', 0.7800032496452332),
#  ('feito', 0.7623869180679321),
#  ('efetuada', 0.7578337788581848),
#  ('padronizar', 0.7545948028564453),
#  ('consistir', 0.7490668296813965),
#  ('utilizacao', 0.7430251836776733),
#  ('constar', 0.731905460357666),
#  ('usar', 0.7292234301567078),
#  ('efetuar', 0.7263612747192383),
#  ('realizar', 0.7257644534111023),
#  ('aplicacao', 0.7145078182220459),
#  ('otimizados', 0.7085831165313721),
#  ('escolhido', 0.6992649435997009),
#  ('combinar', 0.6926178932189941),
#  ('avaliar', 0.691973090171814),
#  ('apropriar', 0.6898202300071716)]

# %%
w2v_model.wv.most_similar(positive=['doenca'], topn=20)
# Out:
# [('enfermidade', 0.8555589914321899),
#  ('cronicidade', 0.8292268514633179),
#  ('manifestacao', 0.8153039216995239),
#  ('debilitante', 0.7879472970962524),
#  ('imunodepressao', 0.7567734718322754),
#  ('agravamento', 0.7558344602584839),
#  ('etiologia', 0.7548041939735413),
#  ('patologia', 0.7503139972686768),
#  ('agravar', 0.7469655871391296),
#  ('multissistemica', 0.740765392780304),
#  ('doencas', 0.7339187860488892),
#  ('cronicar', 0.7304139733314514),
#  ('cronicar_degenerativo', 0.728778600692749),
#  ('incapacitante', 0.7244681715965271),
#  ('afeccao', 0.7204703688621521),
#  ('incuravel', 0.7192423343658447),
#  ('molestia', 0.7191190719604492),
#  ('etiologia_multifatorial', 0.7166198492050171),
#  ('cardiopatia', 0.7151302099227905),
#  ('entidade_clinicar', 0.7106862664222717)]

# %%
w2v_model.wv.most_similar(positive=['febre'], topn=20)
# Out:
# [('amarella', 0.8731637001037598),
#  ('exantema', 0.8669957518577576),
#  ('dor_abdominal', 0.8601210117340088),
#  ('bilioso', 0.8518357276916504),
#  ('ictericia', 0.8416718244552612),
#  ('purpurica', 0.8295959830284119),
#  ('epigastralgia', 0.8178759813308716),
#  ('vomitos', 0.8121721744537354),
#  ('letargiar', 0.8113310933113098),
#  ('linfoadenomegalia', 0.8063106536865234),
#  ('nauseas', 0.798536479473114),
#  ('hemoptise', 0.7984946966171265),
#  ('calafrio', 0.7965927124023438),
#  ('poliartralgia', 0.7898606657981873),
#  ('obstipacao', 0.787319004535675),
#  ('espirro', 0.785427451133728),
#  ('hipereosinofilia', 0.7840197086334229),
#  ('melena', 0.7784633040428162),
#  ('eosinofilia', 0.7782590389251709),
#  ('hematemese', 0.7778492569923401)]

# %%
w2v_model.wv.most_similar(positive=['hipertensao'], topn=20)
# Out:
# [('hipertensao_arterial', 0.9375797510147095),
#  ('diabete', 0.887750506401062),
#  ('diabete_mellitus', 0.8700491189956665),
#  ('diabete_melito', 0.844074010848999),
#  ('renovascular', 0.8381986021995544),
#  ('doenca_coronariana', 0.8235231637954712),
#  ('dislipidemia', 0.8191030025482178),
#  ('doenca_cardiovascular', 0.7991654872894287),
#  ('diabete_hipertensao', 0.797847330570221),
#  ('sistemica_has', 0.7906119227409363),
#  ('dm', 0.766046404838562),
#  ('has', 0.7640104293823242),
#  ('obesidade', 0.756833016872406),
#  ('hipertenso', 0.7545467019081116),
#  ('descompensar', 0.7440673112869263),
#  ('hiperlipidemia', 0.740421712398529),
#  ('nefropatia_diabetica', 0.7273709774017334),
#  ('hipertensao_diabete', 0.7267354130744934),
#  ('hta', 0.7208558917045593),
#  ('pressao_arterial', 0.7147016525268555)]

# %%
w2v_model.wv.most_similar(positive=['leishmaniose'], topn=20)
# Out:
# [('esporotricose', 0.8431519269943237),
#  ('leishmaniose_cutanea', 0.7968167066574097),
#  ('leishmaniose_tegumentar', 0.792050302028656),
#  ('leishmaniose_visceral', 0.7732083797454834),
#  ('calazar', 0.771430253982544),
#  ('lta', 0.7680327892303467),
#  ('area_endemica', 0.7571614980697632),
#  ('micose', 0.7453235387802124),
#  ('espundia', 0.7423174977302551),
#  ('paracoccidioidomicose', 0.7350411415100098),
#  ('histoplasmose', 0.7277938723564148),
#  ('estrongiloidiase', 0.7245544791221619),
#  ('mucocutanea', 0.7199079990386963),
#  ('cutaneo_mucoso', 0.7198944091796875),
#  ('esquistossomose', 0.7130339741706848),
#  ('lva', 0.7082318067550659),
#  ('esquistossomose_mansoni', 0.7046831846237183),
#  ('arboviroses', 0.7039405703544617),
#  ('helicobacter_pylori', 0.7035027146339417),
#  ('parasitose', 0.7030550241470337)]

# %%
w2v_model.wv.most_similar(positive=['lepra'], topn=20)
# Out:
# [('bouba', 0.7866853475570679),
#  ('antituberculoso', 0.7778962850570679),
#  ('reagudizacao', 0.730250895023346),
#  ('leproso', 0.7278895974159241),
#  ('variola', 0.7255570888519287),
#  ('lepromatosa', 0.7228238582611084),
#  ('peste', 0.7130700349807739),
#  ("mal'aria", 0.7118841409683228),
#  ('dispensarios', 0.7059882879257202),
#  ('quarentenar', 0.701519250869751),
#  ('radium', 0.6952753067016602),
#  ('infectocontagiosas', 0.6867738962173462),
#  ('febre_amarelo', 0.6841538548469543),
#  ('hepatite_virar', 0.6833884119987488),
#  ('meningococicas', 0.6808549761772156),
#  ('raivar_humano', 0.6746015548706055),
#  ('meningite_tuberculoso', 0.6716326475143433),
#  ('tuberculoso', 0.665798544883728),
#  ('pandemia', 0.6647205352783203),
#  ('miasmar', 0.6644881963729858)]

# %%
w2v_model.wv.most_similar(positive=['virus'], topn=20)
# Out:
# [('hhv', 0.8083161115646362),
#  ('amarilico', 0.8068985342979431),
#  ('parvovirus_b', 0.804229736328125),
#  ('herpesvirus', 0.7962015867233276),
#  ('rotavirus', 0.7954397201538086),
#  ('viral', 0.7936084866523743),
#  ('poliovirus', 0.7905912399291992),
#  ('virus_dengue', 0.7891302108764648),
#  ('adenovirus', 0.7864426374435425),
#  ('virar', 0.7673022150993347),
#  ('oncogenicos', 0.7668913006782532),
#  ('metapneumovirus', 0.7645242214202881),
#  ('enterovirus', 0.7581526041030884),
#  ('coxsackie', 0.7542142868041992),
#  ('arbovirus', 0.7530077695846558),
#  ('flavivirus', 0.752346396446228),
#  ('bpv', 0.7515954971313477),
#  ('virus_gripar', 0.7511411309242249),
#  ('sorotipo', 0.7488754987716675),
#  ('virus_influenza', 0.7466599941253662)]

# %%
w2v_model.wv.most_similar(positive=['tumor'], topn=20)
# Out:
# [('tumor_benigno', 0.9054811000823975),
#  ('sarcoma', 0.8905618190765381),
#  ('tumor_malignar', 0.881975531578064),
#  ('carcinoma', 0.8799875974655151),
#  ('neoplasia_benigno', 0.8549938797950745),
#  ('tumor_maligno', 0.8537380695343018),
#  ('neoplasia', 0.8444377779960632),
#  ('lesoes_benigno', 0.8441123962402344),
#  ('adenoma', 0.8437439203262329),
#  ('metastases', 0.8358466625213623),
#  ('adenocarcinoma', 0.832629382610321),
#  ('neoplasia_maligno', 0.8318486213684082),
#  ('benigno_maligno', 0.8229876160621643),
#  ('hee', 0.8213528990745544),
#  ('adenocarcinomas', 0.8137218952178955),
#  ('metastases_distanciar', 0.8125420212745667),
#  ('tumor_primarios', 0.8094319105148315),
#  ('tumor_primario', 0.8085724711418152),
#  ('neuroblastoma', 0.7999927401542664),
#  ('linfoma', 0.7985855340957642)]

# %%
w2v_model.wv.most_similar(positive=['febre'], topn=20)
# Out:
# [('amarella', 0.8731637001037598),
#  ('exantema', 0.8669957518577576),
#  ('dor_abdominal', 0.8601210117340088),
#  ('bilioso', 0.8518357276916504),
#  ('ictericia', 0.8416718244552612),
#  ('purpurica', 0.8295959830284119),
#  ('epigastralgia', 0.8178759813308716),
#  ('vomitos', 0.8121721744537354),
#  ('letargiar', 0.8113310933113098),
#  ('linfoadenomegalia', 0.8063106536865234),
#  ('nauseas', 0.798536479473114),
#  ('hemoptise', 0.7984946966171265),
#  ('calafrio', 0.7965927124023438),
#  ('poliartralgia', 0.7898606657981873),
#  ('obstipacao', 0.787319004535675),
#  ('espirro', 0.785427451133728),
#  ('hipereosinofilia', 0.7840197086334229),
#  ('melena', 0.7784633040428162),
#  ('eosinofilia', 0.7782590389251709),
#  ('hematemese', 0.7778492569923401)]

# %%
w2v_model.wv.most_similar(positive=['lesoes'], topn=20)
# Out:
# [('lesao', 0.8278836607933044),
#  ('lesoes_traumaticas', 0.8247790336608887),
#  ('ulceracoes', 0.7634834051132202),
#  ('lesoes_hepaticas', 0.7557942271232605),
#  ('metastaticas', 0.7505180835723877),
#  ('ulceracao', 0.7451194524765015),
#  ('regiao_cervical', 0.7385658621788025),
#  ('metastases', 0.738038182258606),
#  ('ulcerar', 0.7363412380218506),
#  ('subclinicas', 0.7357546091079712),
#  ('acometimento', 0.734939455986023),
#  ('ferimento', 0.7288352251052856),
#  ('isquemicas', 0.7240350246429443),
#  ('contraturas', 0.7224602699279785),
#  ('lesoes_osseas', 0.714593231678009),
#  ('partir_mole', 0.7124183773994446),
#  ('cicatrizar', 0.7106053233146667),
#  ('maligno', 0.7102433443069458),
#  ('alteracoes_anatomicas', 0.7097575068473816),
#  ('afeccoes', 0.7094008922576904)]

# %%
w2v_model.wv.most_similar(positive=['bacteria'], topn=20)
# Out:
# [('microrganismo', 0.895549476146698),
#  ('bacterias', 0.8537545800209045),
#  ('patogeno', 0.8521144390106201),
#  ('microorganismo', 0.8395262956619263),
#  ('fungar', 0.8311245441436768),
#  ('micro_organismo', 0.8237854838371277),
#  ('bacterias_patogenicas', 0.8172075748443604),
#  ('saprofitas', 0.8158867955207825),
#  ('gram_positivo', 0.8119640350341797),
#  ('salmonela', 0.804446816444397),
#  ('gram_negativo', 0.8003702163696289),
#  ('coli', 0.8003031611442566),
#  ('microrganismos', 0.7937945127487183),
#  ('endotoxina', 0.7914307117462158),
#  ('l_monocytogenes', 0.7885932326316833),
#  ('patogenos', 0.7884089946746826),
#  ('probioticas', 0.7869670391082764),
#  ('virulencia', 0.7808605432510376),
#  ('micoplasma', 0.7807498574256897),
#  ('micoplasmas', 0.7758751511573792)]

# %%
w2v_model.wv.most_similar(positive=['anticorpo'], topn=20)
# Out:
# [('anticorpo_igg', 0.9078617095947266),
#  ('anticorpo_igm', 0.8985974788665771),
#  ('igg', 0.8968866467475891),
#  ('aloanticorpos', 0.8740679025650024),
#  ('presenca_anticorpo', 0.8725489377975464),
#  ('anticorpo_especificos', 0.869660496711731),
#  ('aglutinina', 0.8674484491348267),
#  ('imunoglobulina_g', 0.8594392538070679),
#  ('anticorpo_neutralizante', 0.8572835922241211),
#  ('anticorpo_anti', 0.8536890745162964),
#  ('subclasse', 0.8506932258605957),
#  ('titulos_anticorpo', 0.8379318714141846),
#  ('vha', 0.8330768942832947),
#  ('antieritrocitarios', 0.826634407043457),
#  ('igg_igm', 0.8225702047348022),
#  ('antivha', 0.8162748217582703),
#  ('deteccao_anticorpo', 0.8114060759544373),
#  ('igm', 0.8076145052909851),
#  ('igm_anti', 0.7997551560401917),
#  ('antisoro', 0.7942496538162231)]

# %%
w2v_model.wv.most_similar(positive=['parasitario'], topn=20)
# Out:
# [('ascaris_lumbricoides', 0.7597793936729431),
#  ('peritonite', 0.7285875082015991),
#  ('hiperinfeccao', 0.7169147729873657),
#  ('strongyloides_stercoralis', 0.7100154161453247),
#  ('eosinofilica', 0.6951195597648621),
#  ('trichuris_trichiura', 0.6851383447647095),
#  ('capsalideos', 0.6809260845184326),
#  ('enterobius', 0.6768419742584229),
#  ('trieuriase', 0.67513108253479),
#  ('monogenoides', 0.6734041571617126),
#  ('sanguineus', 0.6708177924156189),
#  ('hipereosinofilia', 0.6578975319862366),
#  ('brando', 0.6547888517379761),
#  ('esquistossomotico', 0.6522166728973389),
#  ('taenia', 0.6462410688400269),
#  ('ovipositora', 0.6458261013031006),
#  ('hematogenea', 0.6457524299621582),
#  ('hymenolepis_nanar', 0.6454809308052063),
#  ('rivolta', 0.6454726457595825),
#  ('gigliolii', 0.6444995403289795)]

# %% [markdown]
# ### Passo 3 - Grau de similaridade
# Agora, vamos medir o quanto duas palavras são similarses, ou seja, o quanto elas aparecem no mesmo contexto ao longo dos sete livros.

# %%
w2v_model.wv.similarity("doenca", 'dor')
# Out:
# 0.37753552

# %%
w2v_model.wv.similarity("pessoa", 'inseto')
# Out:
# 0.042850576

# %% [markdown]
# ### Passo 4 - Palavra fora de contexto
# Das palavras enviadas, qual está fora do contexto?
#
# Vimos que às vezes os resultados não fazem muito sentido para nós, humanos.. Lembre-se de que isso foi gerado de acordo com a forma em que as palavras estavam em nosso corpus.

# %%
w2v_model.wv.doesnt_match(['hipertireoidismo', 'sal', 'carboidrato'])
# Out:
# 'hipertireoidismo'

# %%
w2v_model.wv.doesnt_match(['febres', 'tumor', 'virus'])
# Out:
# 'tumor'

# %% [markdown]
# ### Passo 5 - Analogias
#
# Qual palavra está para **terra** assim como **chuva** está para **sol**?

# %%
w2v_model.wv.most_similar(positive=["tumor", "virus"], negative=["bacteria"], topn=3)
# Out:
# [('leucemia', 0.6969778537750244),
#  ('tumor_maligno', 0.6966079473495483),
#  ('supratentoriais', 0.6902815699577332)]

# %%
w2v_model.wv.most_similar(positive=["montanha", "nuvem"], negative=["casa"], topn=3)
# Out:
# [('nevoar', 0.7380039095878601),
#  ('ceu', 0.7246636152267456),
#  ('florestar_proibir', 0.7180446982383728)]

# %%
w2v_model.wv.most_similar(positive=["escola", "sala"], negative=["trem"], topn=3)
# Out:
# [('limite', 0.6873146891593933),
#  ('alunar', 0.6806097030639648),
#  ('estudante', 0.6531786918640137)]

# %% [markdown]
# ### Passo 6 - Top palavras mais e menos similares

# %%
w2v_model.wv.most_similar(positive=["doenca"],topn=3)
# Out:
# [('enfermidade', 0.8555589914321899),
#  ('cronicidade', 0.8292268514633179),
#  ('manifestacao', 0.8153039216995239)]

# %%
w2v_model.wv.most_similar(negative=["doenca"],topn=3)
# Out:
# [('uniden', 0.6329104900360107),
#  ('azolla', 0.6197797060012817),
#  ('fracionados', 0.6133755445480347)]

# %% [markdown]
# ### Passo 7 - Visualização t-SNE
# Vamos plotar nossos vetores de 32 dimensões em gráficos bidimensionais para tentar encontrar padrões interessantes.
#
# Para isso, usaremos a implementação ```t-SNE``` do ```scikit-learn```.
#
# Para tornar as visualizações mais relevantes, examinaremos as relações entre uma palavra de consulta (em vermelho), suas palavras mais semelhantes no modelo (em azul) e outras palavras do vocabulário (em verde).

# %%
def tsnescatterplot(model, word, list_names):
    # Plota os resultados do algoritmo de redução de dimensionalidade t-SNE dos vetores de uma palavra de consulta,
    # sua lista de palavras mais semelhantes e uma lista de palavras.
    arrays = np.empty((0, 32), dtype='f')
    word_labels = [word]
    color_list  = ['red']

    # adiciona o vetor da palavra de consulta
    arrays = np.append(arrays, model.wv.__getitem__([word]), axis=0)
    
    # pega a lsita das palavras mais similares
    close_words = model.wv.most_similar([word])
    
    # adiciona o vetor de cada uma das palavras mais proximas no array
    for wrd_score in close_words:
        wrd_vector = model.wv.__getitem__([wrd_score[0]])
        word_labels.append(wrd_score[0])
        color_list.append('blue')
        arrays = np.append(arrays, wrd_vector, axis=0)

        
    # adiciona o vetor de cada uma das palavras da lista list_names ao array
    for wrd in list_names:
        wrd_vector = model.wv.__getitem__([wrd])
        word_labels.append(wrd)
        color_list.append('green')
        arrays = np.append(arrays, wrd_vector, axis=0)
                
    # Reduz a dimensionalidade com PCA
    reduc = PCA(n_components=18).fit_transform(arrays)
    
    # Encontra as coorendadas t-SNE para duas dimensoes
    np.set_printoptions(suppress=True)
    
    Y = TSNE(n_components=2, random_state=0, perplexity=15).fit_transform(reduc)
    
    # Seta as variaveis para plotar
    df = pd.DataFrame({'x': [x for x in Y[:, 0]],
                       'y': [y for y in Y[:, 1]],
                       'words': word_labels,
                       'color': color_list})
    
    fig, _ = plt.subplots()
    fig.set_size_inches(9, 9)
    
    # Grafico basico
    p1 = sns.regplot(data=df,
                     x="x",
                     y="y",
                     fit_reg=False,
                     marker="o",
                     scatter_kws={'s': 40,
                                  'facecolors': df['color']
                                 }
                    )
    
    # Adiciona anotações com um loop
    for line in range(0, df.shape[0]):
         p1.text(df["x"][line],
                 df['y'][line],
                 '  ' + df["words"][line].title(),
                 horizontalalignment='left',
                 verticalalignment='bottom', size='medium',
                 color=df['color'][line],
                 weight='normal'
                ).set_size(15)

    
    plt.xlim(Y[:, 0].min()-50, Y[:, 0].max()+50)
    plt.ylim(Y[:, 1].min()-50, Y[:, 1].max()+50)
            
    plt.title('t-SNE visualization for {}'.format(word.title()))

# %%
wordT = 'doenca'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'paciente'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'hipertensao'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'diabete'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'febre'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'aranha'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'dor'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'calafrio'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'nausea'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'sono'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'bacteria'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'estudar'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'quadro'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'hepatico'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'pulmao'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'risco'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'mamografia'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'cancer'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'glandula'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'hemorragia'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'trombose'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %%
wordT = 'grave'
   
tsnescatterplot(w2v_model, wordT, [t[0] for t in w2v_model.wv.most_similar(positive=[wordT], topn=20)])

# %% [markdown]
# Vamos gerar um gráfico diferente agora. Vamos ver como os personagens estão relacionados entre si e quais as 10 palavras mais próximas a cada um deles.

# %%
keys = ['dor', 'febre', 'nausea', 'hipertenso', 'palpitacao', 'sonolencia']


embedding_clusters = []
word_clusters = []
for word in keys:
    embeddings = []
    words = []
    for similar_word, _ in model.wv.most_similar(word, topn=10):
        words.append(similar_word)
        embeddings.append(model[similar_word])
    embedding_clusters.append(embeddings)
    word_clusters.append(words)


from sklearn.manifold import TSNE
import numpy as np

embedding_clusters = np.array(embedding_clusters)
n, m, k = embedding_clusters.shape
tsne_model_en_2d = TSNE(perplexity=15, n_components=2, init='pca', n_iter=3500, random_state=32)
embeddings_en_2d = np.array(tsne_model_en_2d.fit_transform(embedding_clusters.reshape(n * m, k))).reshape(n, m, 2)

import matplotlib.pyplot as plt
import matplotlib.cm as cm

def tsne_plot_similar_words(title, labels, embedding_clusters, word_clusters, a, filename=None):
    plt.figure(figsize=(16, 9))
    colors = cm.rainbow(np.linspace(0, 1, len(labels)))
    for label, embeddings, words, color in zip(labels, embedding_clusters, word_clusters, colors):
        x = embeddings[:, 0]
        y = embeddings[:, 1]
        plt.scatter(x, y, c=color, alpha=a, label=label)
        for i, word in enumerate(words):
            plt.annotate(word, alpha=0.5, xy=(x[i], y[i]), xytext=(5, 2),
                         textcoords='offset points', ha='right', va='bottom', size=16)
    #plt.legend(loc=4)
    plt.legend()
    plt.title(title)
    plt.grid(True)
    if filename:
        plt.savefig(filename, format='png', dpi=300, bbox_inches='tight')
    plt.show()


tsne_plot_similar_words('Similaridade entre palavras associadas aos personagens', keys, embeddings_en_2d, word_clusters, 0.7, 'similar_words_new.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-8ef963746d97> in <module>
#       7     embeddings = []
#       8     words = []
# ----> 9     for similar_word, _ in model.wv.most_similar(word, topn=10):
#      10         words.append(similar_word)
#      11         embeddings.append(model[similar_word])
#
# NameError: name 'model' is not defined

# %% [markdown]
# Será gerado essa imagem:
#
# ![t-SNE](img/tsne.png)

# %% [markdown]
# Agora, vamos [gerar nuvens de palavras](https://github.com/lisaterumi/word2vec-harry-potter-portugues/blob/main/%5B3%5D%20Nuvem-palavra-Harry-Potter.ipynb) para cada um dos livros em separado.
